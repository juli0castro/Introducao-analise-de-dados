# %%
import math
raio = float(input("Digite o raio do círculo: "))
area = math.pi*raio**2
print("A área do círculo de raio {} é {:.2f}". format(raio,area))
# Out:
# Digite o raio do círculo: 2
# A área do círculo de raio 2.0 é 12.57

# %%
import math
C1 = float(input("Digite o valor do cateto1 : "))
C2 = float(input("Digite o valor do cateto2 : "))
hipotenusa = math.sqrt(C1**2+C2**2)
print("o valor da hipotenusa de catetos1 {} e cateto2 {} é {}".format(C1,C2,hipotenusa))
# Out:
# Digite o valor do cateto1 : 3
# Digite o valor do cateto2 : 4
# o valor da hipotenusa de catetos1 3.0 e cateto2 4.0 é 5.0

# %%
import math
Valorproduto = float(input("Digite o valor atual do produto: "))
Novopreço =Valorproduto*0.9
print("O novo preço do produto é {}".format(Novopreço))
# Out:
# Digite o valor atual do produto: 1000
# O novo preço do produto é 900.0

# %%
Valor = float(input("Digite a hora atual: "))
if (Valor <= 12):
  print("Bom dia")
# Out:
# Digite a hora atual: 11
# Bom dia

# %%
import math
Salariofunc = float(input("Digite o salário do funcionario: "))
Salariomin = float(input("Digite o valor do salario minimo: "))
QuantidadeSalarios = Salariofunc/Salariomin
print("A quantidade de salarios minimos baseado no salario do funcionario é {}".format(QuantidadeSalarios))
# Out:
# Digite o salário do funcionario: 14164
# Digite o valor do salario minimo: 111
# A quantidade de salarios minimos baseado no salario do funcionario é 127.6036036036036
